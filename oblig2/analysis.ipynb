# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import scipy.io
import sys

sys.path.append("../")

import glcm

# %%
mosaic1_train = scipy.io.loadmat("mosaic1_train.mat")['mosaicim']

# %%
plt.figure(1, figsize=(10,10))
plt.imshow(mosaic1_train, cmap=plt.cm.gray)

# %%
t1p0m1 = scipy.io.loadmat("texture1_glcmdx0dy-1.mat")['g1d10']
t1p1p0 = scipy.io.loadmat("texture1_glcmdx+1dy0.mat")['g1d01']
t1m1m1 = scipy.io.loadmat("texture1_glcmdx-1dy-1.mat")['g1dmin11']
t1p1m1 = scipy.io.loadmat("texture1_glcmdx+1dy-1.mat")['g1d1min1']

t2p0m1 = scipy.io.loadmat("texture2_glcmdx0dy-1.mat")['g2d10']
t2p1p0 = scipy.io.loadmat("texture2_glcmdx+1dy0.mat")['g2d01']
t2m1m1 = scipy.io.loadmat("texture2_glcmdx-1dy-1.mat")['g2dmin11']
t2p1m1 = scipy.io.loadmat("texture2_glcmdx+1dy-1.mat")['g2d1min1']

t3p0m1 = scipy.io.loadmat("texture3_glcmdx0dy-1.mat")['g3d10']
t3p1p0 = scipy.io.loadmat("texture3_glcmdx+1dy0.mat")['g3d01']
t3m1m1 = scipy.io.loadmat("texture3_glcmdx-1dy-1.mat")['g3dmin11']
t3p1m1 = scipy.io.loadmat("texture3_glcmdx+1dy-1.mat")['g3d1min1']

t4p0m1 = scipy.io.loadmat("texture4_glcmdx0dy-1.mat")['g4d10']
t4p1p0 = scipy.io.loadmat("texture4_glcmdx+1dy0.mat")['g4d01']
t4m1m1 = scipy.io.loadmat("texture4_glcmdx-1dy-1.mat")['g4dmin11']
t4p1m1 = scipy.io.loadmat("texture4_glcmdx+1dy-1.mat")['g4d1min1']

# %%
arr = [t1p0m1, t1p1p0, t1m1m1, t1p1m1, t2p0m1, t2p1p0, t2m1m1, t2p1m1, t3p0m1, t3p1p0, t3m1m1, t3p1m1, t4p0m1, t4p1p0, t4m1m1, t4p1m1]
tit = ["(+0, -1)", "(+1, +0)", "(-1, -1)", "(+1, -1)"]
plt.figure(1, figsize=(12, 12))

for i, f in enumerate(arr):
    plt.subplot(4, 4, i+1)
    if i < 4:
        plt.title(tit[i])
plt.show()

# %% [markdown]
# I hereby select feature 1 and 2.

# %%
g11 = glcm.glcm(mosaic1_train[0:256, 0:256], size=31, stride=1, levels=16, dx=0, dy=-1)

# %%
g12 = glcm.glcm(mosaic1_train[0:256, 256:], size=31, stride=1, levels=16, dx=0, dy=-1)
# Out:
# At row 0
# At row 1
# At row 2
# At row 3
# At row 4
# At row 5
# At row 6
# At row 7
# At row 8
# At row 9
# At row 10
# At row 11
# At row 12
# At row 13
# At row 14
# At row 15
# At row 16
# At row 17
# At row 18
# At row 19
# At row 20
# At row 21
# At row 22
# At row 23
# At row 24
# At row 25
# At row 26
# At row 27
# At row 28
# At row 29
# At row 30
# At row 31
# At row 32
# At row 33
# At row 34
# At row 35
# At row 36
# At row 37
# At row 38
# At row 39
# At row 40
# At row 41
# At row 42
# At row 43
# At row 44
# At row 45
# At row 46
# At row 47
# At row 48
# At row 49
# At row 50
# At row 51
# At row 52
# At row 53
# At row 54
# At row 55
# At row 56
# At row 57
# At row 58
# At row 59
# At row 60
# At row 61
# At row 62
# At row 63
# At row 64
# At row 65
# At row 66
# At row 67
# At row 68
# At row 69
# At row 70
# At row 71
# At row 72
# At row 73
# At row 74
# At row 75
# At row 76
# At row 77
# At row 78
# At row 79
# At row 80
# At row 81
# At row 82
# At row 83
# ...

# %%
g13 = glcm.glcm(mosaic1_train[256:, 0:256], size=31, stride=1, levels=16, dx=0, dy=-1)
# Out:
# At row 0
# At row 1
# At row 2
# At row 3
# At row 4
# At row 5
# At row 6
# At row 7
# At row 8
# At row 9
# At row 10
# At row 11
# At row 12
# At row 13
# At row 14
# At row 15
# At row 16
# At row 17
# At row 18
# At row 19
# At row 20
# At row 21
# At row 22
# At row 23
# At row 24
# At row 25
# At row 26
# At row 27
# At row 28
# At row 29
# At row 30
# At row 31
# At row 32
# At row 33
# At row 34
# At row 35
# At row 36
# At row 37
# At row 38
# At row 39
# At row 40
# At row 41
# At row 42
# At row 43
# At row 44
# At row 45
# At row 46
# At row 47
# At row 48
# At row 49
# At row 50
# At row 51
# At row 52
# At row 53
# At row 54
# At row 55
# At row 56
# At row 57
# At row 58
# At row 59
# At row 60
# At row 61
# At row 62
# At row 63
# At row 64
# At row 65
# At row 66
# At row 67
# At row 68
# At row 69
# At row 70
# At row 71
# At row 72
# At row 73
# At row 74
# At row 75
# At row 76
# At row 77
# At row 78
# At row 79
# At row 80
# At row 81
# At row 82
# At row 83
# ...

# %%
g14 = glcm.glcm(mosaic1_train[256:, 256:], size=31, stride=1, levels=16, dx=0, dy=-1)
# Out:
# At row 0
# At row 1
# At row 2
# At row 3
# At row 4
# At row 5
# At row 6
# At row 7
# At row 8
# At row 9
# At row 10
# At row 11
# At row 12
# At row 13
# At row 14
# At row 15
# At row 16
# At row 17
# At row 18
# At row 19
# At row 20
# At row 21
# At row 22
# At row 23
# At row 24
# At row 25
# At row 26
# At row 27
# At row 28
# At row 29
# At row 30
# At row 31
# At row 32
# At row 33
# At row 34
# At row 35
# At row 36
# At row 37
# At row 38
# At row 39
# At row 40
# At row 41
# At row 42
# At row 43
# At row 44
# At row 45
# At row 46
# At row 47
# At row 48
# At row 49
# At row 50
# At row 51
# At row 52
# At row 53
# At row 54
# At row 55
# At row 56
# At row 57
# At row 58
# At row 59
# At row 60
# At row 61
# At row 62
# At row 63
# At row 64
# At row 65
# At row 66
# At row 67
# At row 68
# At row 69
# At row 70
# At row 71
# At row 72
# At row 73
# At row 74
# At row 75
# At row 76
# At row 77
# At row 78
# At row 79
# At row 80
# At row 81
# At row 82
# At row 83
# ...

# %%
g21 = glcm.glcm(mosaic1_train[0:256, 0:256], size=31, stride=1, levels=16, dx=1, dy=0)
# Out:
# At row 0
# At row 1
# At row 2
# At row 3
# At row 4
# At row 5
# At row 6
# At row 7
# At row 8
# At row 9
# At row 10
# At row 11
# At row 12
# At row 13
# At row 14
# At row 15
# At row 16
# At row 17
# At row 18
# At row 19
# At row 20
# At row 21
# At row 22
# At row 23
# At row 24
# At row 25
# At row 26
# At row 27
# At row 28
# At row 29
# At row 30
# At row 31
# At row 32
# At row 33
# At row 34
# At row 35
# At row 36
# At row 37
# At row 38
# At row 39
# At row 40
# At row 41
# At row 42
# At row 43
# At row 44
# At row 45
# At row 46
# At row 47
# At row 48
# At row 49
# At row 50
# At row 51
# At row 52
# At row 53
# At row 54
# At row 55
# At row 56
# At row 57
# At row 58
# At row 59
# At row 60
# At row 61
# At row 62
# At row 63
# At row 64
# At row 65
# At row 66
# At row 67
# At row 68
# At row 69
# At row 70
# At row 71
# At row 72
# At row 73
# At row 74
# At row 75
# At row 76
# At row 77
# At row 78
# At row 79
# At row 80
# At row 81
# At row 82
# At row 83
# ...

# %%
g22 = glcm.glcm(mosaic1_train[0:256, 256:], size=31, stride=1, levels=16, dx=1, dy=0)
# Out:
# At row 0
# At row 1
# At row 2
# At row 3
# At row 4
# At row 5
# At row 6
# At row 7
# At row 8
# At row 9
# At row 10
# At row 11
# At row 12
# At row 13
# At row 14
# At row 15
# At row 16
# At row 17
# At row 18
# At row 19
# At row 20
# At row 21
# At row 22
# At row 23
# At row 24
# At row 25
# At row 26
# At row 27
# At row 28
# At row 29
# At row 30
# At row 31
# At row 32
# At row 33
# At row 34
# At row 35
# At row 36
# At row 37
# At row 38
# At row 39
# At row 40
# At row 41
# At row 42
# At row 43
# At row 44
# At row 45
# At row 46
# At row 47
# At row 48
# At row 49
# At row 50
# At row 51
# At row 52
# At row 53
# At row 54
# At row 55
# At row 56
# At row 57
# At row 58
# At row 59
# At row 60
# At row 61
# At row 62
# At row 63
# At row 64
# At row 65
# At row 66
# At row 67
# At row 68
# At row 69
# At row 70
# At row 71
# At row 72
# At row 73
# At row 74
# At row 75
# At row 76
# At row 77
# At row 78
# At row 79
# At row 80
# At row 81
# At row 82
# At row 83
# ...

# %%
g23 = glcm.glcm(mosaic1_train[256:, 0:256], size=31, stride=1, levels=16, dx=1, dy=0)
# Out:
# At row 0
# At row 1
# At row 2
# At row 3
# At row 4
# At row 5
# At row 6
# At row 7
# At row 8
# At row 9
# At row 10
# At row 11
# At row 12
# At row 13
# At row 14
# At row 15
# At row 16
# At row 17
# At row 18
# At row 19
# At row 20
# At row 21
# At row 22
# At row 23
# At row 24
# At row 25
# At row 26
# At row 27
# At row 28
# At row 29
# At row 30
# At row 31
# At row 32
# At row 33
# At row 34
# At row 35
# At row 36
# At row 37
# At row 38
# At row 39
# At row 40
# At row 41
# At row 42
# At row 43
# At row 44
# At row 45
# At row 46
# At row 47
# At row 48
# At row 49
# At row 50
# At row 51
# At row 52
# At row 53
# At row 54
# At row 55
# At row 56
# At row 57
# At row 58
# At row 59
# At row 60
# At row 61
# At row 62
# At row 63
# At row 64
# At row 65
# At row 66
# At row 67
# At row 68
# At row 69
# At row 70
# At row 71
# At row 72
# At row 73
# At row 74
# At row 75
# At row 76
# At row 77
# At row 78
# At row 79
# At row 80
# At row 81
# At row 82
# At row 83
# ...

# %%
g24 = glcm.glcm(mosaic1_train[256:, 256:], size=31, stride=1, levels=16, dx=1, dy=0)
# Out:
# At row 0
# At row 1
# At row 2
# At row 3
# At row 4
# At row 5
# At row 6
# At row 7
# At row 8
# At row 9
# At row 10
# At row 11
# At row 12
# At row 13
# At row 14
# At row 15
# At row 16
# At row 17
# At row 18
# At row 19
# At row 20
# At row 21
# At row 22
# At row 23
# At row 24
# At row 25
# At row 26
# At row 27
# At row 28
# At row 29
# At row 30
# At row 31
# At row 32
# At row 33
# At row 34
# At row 35
# At row 36
# At row 37
# At row 38
# At row 39
# At row 40
# At row 41
# At row 42
# At row 43
# At row 44
# At row 45
# At row 46
# At row 47
# At row 48
# At row 49
# At row 50
# At row 51
# At row 52
# At row 53
# At row 54
# At row 55
# At row 56
# At row 57
# At row 58
# At row 59
# At row 60
# At row 61
# At row 62
# At row 63
# At row 64
# At row 65
# At row 66
# At row 67
# At row 68
# At row 69
# At row 70
# At row 71
# At row 72
# At row 73
# At row 74
# At row 75
# At row 76
# At row 77
# At row 78
# At row 79
# At row 80
# At row 81
# At row 82
# At row 83
# ...

# %%
np.save("g11.npy", g11)
np.save("g12.npy", g12)
np.save("g13.npy", g13)
np.save("g14.npy", g14)
np.save("g21.npy", g21)
np.save("g22.npy", g22)
np.save("g23.npy", g23)
np.save("g24.npy", g24)

# %%
plt.subplot(141)
plt.imshow(glcm.quadrant(g11, 0, 0, 8, 8))
plt.subplot(142)
plt.imshow(glcm.quadrant(g11, 0, 8, 8, 16))
plt.subplot(143)
plt.imshow(glcm.quadrant(g11, 8, 0, 16, 8))
plt.subplot(144)
plt.imshow(glcm.quadrant(g11, 8, 8, 16, 16))

# %%
plt.subplot(141)
plt.imshow(glcm.quadrant(g12, 0, 0, 8, 8))
plt.subplot(142)
plt.imshow(glcm.quadrant(g12, 0, 8, 8, 16))
plt.subplot(143)
plt.imshow(glcm.quadrant(g12, 8, 0, 16, 8))
plt.subplot(144)
plt.imshow(glcm.quadrant(g12, 8, 8, 16, 16))

# %%
plt.subplot(141)
plt.imshow(glcm.quadrant(g13, 0, 0, 8, 8))
plt.subplot(142)
plt.imshow(glcm.quadrant(g13, 0, 8, 8, 16))
plt.subplot(143)
plt.imshow(glcm.quadrant(g13, 8, 0, 16, 8))
plt.subplot(144)
plt.imshow(glcm.quadrant(g13, 8, 8, 16, 16))

# %%
plt.subplot(141)
plt.imshow(glcm.quadrant(g14, 0, 0, 8, 8))
plt.subplot(142)
plt.imshow(glcm.quadrant(g14, 0, 8, 8, 16))
plt.subplot(143)
plt.imshow(glcm.quadrant(g14, 8, 0, 16, 8))
plt.subplot(144)
plt.imshow(glcm.quadrant(g14, 8, 8, 16, 16))

# %%
plt.subplot(141)
plt.imshow(glcm.quadrant(g21, 0, 0, 8, 8))
plt.subplot(142)
plt.imshow(glcm.quadrant(g21, 0, 8, 8, 16))
plt.subplot(143)
plt.imshow(glcm.quadrant(g21, 8, 0, 16, 8))
plt.subplot(144)
plt.imshow(glcm.quadrant(g21, 8, 8, 16, 16))

# %%
plt.subplot(141)
plt.imshow(glcm.quadrant(g22, 0, 0, 8, 8))
plt.subplot(142)
plt.imshow(glcm.quadrant(g22, 0, 8, 8, 16))
plt.subplot(143)
plt.imshow(glcm.quadrant(g22, 8, 0, 16, 8))
plt.subplot(144)
plt.imshow(glcm.quadrant(g22, 8, 8, 16, 16))

# %%
plt.subplot(141)
plt.imshow(glcm.quadrant(g23, 0, 0, 8, 8))
plt.subplot(142)
plt.imshow(glcm.quadrant(g23, 0, 8, 8, 16))
plt.subplot(143)
plt.imshow(glcm.quadrant(g23, 8, 0, 16, 8))
plt.subplot(144)
plt.imshow(glcm.quadrant(g23, 8, 8, 16, 16))

# %%
plt.subplot(141)
plt.imshow(glcm.quadrant(g24, 0, 0, 8, 8))
plt.subplot(142)
plt.imshow(glcm.quadrant(g24, 0, 8, 8, 16))
plt.subplot(143)
plt.imshow(glcm.quadrant(g24, 8, 0, 16, 8))
plt.subplot(144)
plt.imshow(glcm.quadrant(g24, 8, 8, 16, 16))

# %%
feats = [[g11, g12, g13, g14], [g21, g22, g23, g24]]

# %%
X = []
Y = []

for q in [0, 1, 2, 3]:
    features = []
    for gin in [0, 1]:
        g = feats[gin][q]
        for quad in [(0, 0, 8, 8), (0, 8, 8, 16), (8, 8, 16, 16)]:
            m = glcm.quadrant(g, quad).flatten()
            features.append(m)
            
    features = np.array(features)
    X.append(features.transpose((1,0)))
    Y.append(np.array([q] * features.shape[1]))

X = np.vstack(X)
Y = np.concatenate(Y)
# Out:
# 6
# (6, 51076)
# PLEW (51076, 6)
# PLO (51076,)
# 6
# (6, 51076)
# PLEW (102152, 6)
# PLO (102152,)
# 6
# (6, 51076)
# PLEW (153228, 6)
# PLO (153228,)
# 6
# (6, 51076)
# PLEW (204304, 6)
# PLO (204304,)

# %%
reload(gaussian)
# Out:
# <module 'gaussian' from '../gaussian.py'>

# %%
X -= X.mean(0)
X /= X.std(0)
fit.mean
# Out:
# defaultdict(<function <lambda> at 0x7f0b7c11c668>, {0: array([-0.80640932,  0.66274482,  0.83911871, -0.85354373,  0.62841762,
#         0.76913277]), 1: array([-1.04948759,  1.13381932,  0.97919832, -0.92658612, -0.15540253,
#         1.10976176]), 2: array([ 0.72544743, -0.68537956, -0.71777789,  0.57050386,  0.70836635,
#        -0.88430367]), 3: array([ 1.13044948, -1.11118458, -1.10053914,  1.20962599, -1.18138144,
#        -0.99459086])})

# %%
fit = gaussian.GaussianClassifier(covar_type='multiple')
fit.train(X, Y)
# Out:
# [0 1 2 3]
# defaultdict(<function <lambda> at 0x7f0b7c239e60>, {0: array([-0.80640932,  0.66274482,  0.83911871, -0.85354373,  0.62841762,
#         0.76913277]), 1: array([-1.04948759,  1.13381932,  0.97919832, -0.92658612, -0.15540253,
#         1.10976176]), 2: array([ 0.72544743, -0.68537956, -0.71777789,  0.57050386,  0.70836635,
#        -0.88430367]), 3: array([ 1.13044948, -1.11118458, -1.10053914,  1.20962599, -1.18138144,
#        -0.99459086])})
# defaultdict(<type 'int'>, {0: 51076, 1: 51076, 2: 51076, 3: 51076})
# defaultdict(<type 'float'>, {0: 0.25, 1: 0.25, 2: 0.25, 3: 0.25})
# {0: array([[ 0.0901382 , -0.0227558 , -0.11514457,  0.09749378, -0.02362028,
#         -0.10365283],
#        [-0.0227558 ,  0.0750558 ,  0.00023618, -0.01674525,  0.03111233,
#          0.00892642],
#        [-0.11514457,  0.00023618,  0.15908229, -0.12781353,  0.01971125,
#          0.1395806 ],
#        [ 0.09749378, -0.01674525, -0.12781353,  0.10805835, -0.03289693,
# ...

# %%
Ypred = fit.predict(X)
# Out:
# B nan
# B2 -1.1132440156e-35
# B -80.7050669914
# B2 8.91732805572e-36
# B -79.8368189237
# B2 2.12476101204e-35
# B nan
# B2 -1.16840862879e-38
# {0: 35.533881222607874, 1: 29.777704334040326, 2: 7.9341563880941504, 3: -1.1789231139370191}
# {0: 33.262095967923784, 1: 15.545117936661493, 2: 13.118884864160275, 3: -16.643839759178523}
# {0: 34.641069210943186, 1: 35.381295301177417, 2: -30.584052665149688, 3: -143.85826659659992}
# {0: 37.546759043830185, 1: 26.952765689126146, 2: -0.68525289177648929, 3: -64.397688804475621}
# {0: 36.942305455630915, 1: 32.348513263780973, 2: -16.787094977575929, 3: -81.220399155333013}
# {0: 36.83719385270193, 1: 30.731901402135783, 2: 11.884029986624352, 3: 1.6207513222920689}
# {0: 34.404288156239772, 1: 31.358378239499579, 2: -37.486071608293202, 3: -176.55654109617282}
# {0: 35.903610157448952, 1: 28.177196788018797, 2: 5.5195374703230726, 3: -50.218544215378444}
# ...

# %%
Ypred.sum()
# Out:
# 307295.0

# %%
(Ypred == Y).sum() / float(Ypred.shape[0])
# Out:
# 0.96659879395410764

# %%
fig = plt.figure(1, figsize=(20,20))
stride = 1000
for f1 in xrange(0, 6):
    for f2 in xrange(0, 6):
        ax = fig.add_subplot(6, 6, 1 + f1 * 6 + f2)
        plt.scatter(X[::stride,f1], X[::stride,f2], c=plt.cm.rainbow(Y[::stride]/4.0))
        for lab in fit.labels:
            gaussian.plot_cov_ellipse(fit.sigma[lab][[[f1], [f2]],[f1, f2]], fit.mean[lab][[f1, f2]], ax=ax, color=plt.cm.rainbow(lab/4.0))
plt.show()

# %%
print fit.mean[0][[0,1]]
print fit.sigma[0][slice(0,2),slice(0,2)]
print np.linalg.det(fit.sigma[3])
print plt.cm
# Out:
# [-0.80640932  0.66274482]
# [[ 0.0901382 -0.0227558]
#  [-0.0227558  0.0750558]]
# -1.16840862879e-38
# <module 'matplotlib.cm' from '/usr/lib/python2.7/dist-packages/matplotlib/cm.pyc'>

# %%
mosaic2_test = scipy.io.loadmat("mosaic2_test.mat")['mosaicim']

# %%
reload(glcm)
# Out:
# <module 'glcm' from '../glcm.py'>

# %%
plt.imshow(mosaic2_test, cmap=plt.cm.gray)
